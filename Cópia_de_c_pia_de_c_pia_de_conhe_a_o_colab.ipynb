# %% [markdown]
# <a href="https://colab.research.google.com/github/Anderson01fcg/CONECTA-CONCURSOS/blob/main/C%C3%B3pia_de_c_pia_de_c_pia_de_conhe_a_o_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, banca=None, link_banca=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),  # Converter o estado para maiúsculo para facilitar a busca
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos
adicionar_concurso("Concurso Polícia Federal", "RJ", "Cebraspe", "https://www.cebraspe.org.br/")
adicionar_concurso("Concurso Guarda Municipal", "SP", "Vunesp", "https://www.vunesp.com.br/")
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "IBGP") # Exemplo sem link da banca
adicionar_concurso("Concurso Professor Estadual", "RJ") # Exemplo com apenas nome e estado

# Vamos ver como está a nossa lista de concursos
print("\nLista de Concursos Adicionados:")
for concurso in lista_de_concursos:
    print(concurso)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
#
# Lista de Concursos Adicionados:
# {'Nome do Concurso': 'Concurso Polícia Federal', 'Estado': 'RJ', 'Banca Responsável': 'Cebraspe', 'Link da Banca Responsável': 'https://www.cebraspe.org.br/'}
# {'Nome do Concurso': 'Concurso Guarda Municipal', 'Estado': 'SP', 'Banca Responsável': 'Vunesp', 'Link da Banca Responsável': 'https://www.vunesp.com.br/'}
# {'Nome do Concurso': 'Concurso Tribunal de Justiça', 'Estado': 'MG', 'Banca Responsável': 'IBGP', 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Professor Estadual', 'Estado': 'RJ', 'Banca Responsável': None, 'Link da Banca Responsável': None}

# %%
# Função para buscar concursos por estado
def buscar_concursos_por_estado(estado_busca):
    estado_busca_upper = estado_busca.upper()
    concursos_encontrados = []
    for concurso in lista_de_concursos:
        if concurso['Estado'] == estado_busca_upper:
            concursos_encontrados.append(concurso)

    if concursos_encontrados:
        print(f"\nConcursos encontrados para o estado de '{estado_busca}':")
        for concurso in concursos_encontrados:
            print(f"- {concurso['Nome do Concurso']}", end=" ")
            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print(f"\nNenhum concurso encontrado para o estado de '{estado_busca}'.")

# Exemplo de como usar a função de busca
estado_para_buscar = input("Digite o estado que você deseja buscar: ")
buscar_concursos_por_estado(estado_para_buscar)
# Out:
# Digite o estado que você deseja buscar: RJ
#
# Concursos encontrados para o estado de 'RJ':
# - Concurso Polícia Federal (https://www.cebraspe.org.br/)
# - Concurso Professor Estadual (Link da banca não disponível)

# %%
# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, data_concurso=None, banca=None, link_banca=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Data do Concurso': data_concurso,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo a data)
adicionar_concurso("Concurso Polícia Federal", "RJ", "2025-08-15", "Cebraspe", "https://www.cebraspe.org.br/")
adicionar_concurso("Concurso Guarda Municipal", "SP", "2025-09-22", "Vunesp", "https://www.vunesp.com.br/")
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "2025-10-10", "IBGP")
adicionar_concurso("Concurso Professor Estadual", "RJ", "2025-11-05")

# Vamos ver como está a nossa lista de concursos agora
print("\nLista de Concursos Adicionados (com data):")
for concurso in lista_de_concursos:
    print(concurso)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
#
# Lista de Concursos Adicionados (com data):
# {'Nome do Concurso': 'Concurso Polícia Federal', 'Estado': 'RJ', 'Data do Concurso': '2025-08-15', 'Banca Responsável': 'Cebraspe', 'Link da Banca Responsável': 'https://www.cebraspe.org.br/'}
# {'Nome do Concurso': 'Concurso Guarda Municipal', 'Estado': 'SP', 'Data do Concurso': '2025-09-22', 'Banca Responsável': 'Vunesp', 'Link da Banca Responsável': 'https://www.vunesp.com.br/'}
# {'Nome do Concurso': 'Concurso Tribunal de Justiça', 'Estado': 'MG', 'Data do Concurso': '2025-10-10', 'Banca Responsável': 'IBGP', 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Professor Estadual', 'Estado': 'RJ', 'Data do Concurso': '2025-11-05', 'Banca Responsável': None, 'Link da Banca Responsável': None}

# %%
# Função para listar todos os concursos com data de 2025
def listar_concursos_2025():
    concursos_2025 = []
    for concurso in lista_de_concursos:
        if concurso['Data do Concurso'] and '2025' in concurso['Data do Concurso']:
            concursos_2025.append(concurso)

    if concursos_2025:
        print("\nConcursos com data prevista para 2025:")
        for concurso in concursos_2025:
            print(f"- {concurso['Nome do Concurso']}", end=" ")
            if concurso['Data do Concurso']:
                print(f"(Data: {concurso['Data do Concurso']})", end=" ")
            else:
                print("(Data: A ser definida)", end=" ")
            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print("\nNenhum concurso com data prevista para 2025 foi encontrado.")

# Exemplo de como usar a função para listar concursos de 2025
listar_concursos_2025()

# A busca por estado continua funcionando normalmente com a linha existente:
estado_para_buscar = input("Digite o estado que você deseja buscar: ")
buscar_concursos_por_estado(estado_para_buscar)
# Out:
# Concursos com data prevista para 2025:
# - Concurso Polícia Federal (Data: 2025-08-15) (https://www.cebraspe.org.br/)
# - Concurso Guarda Municipal (Data: 2025-09-22) (https://www.vunesp.com.br/)
# - Concurso Tribunal de Justiça (Data: 2025-10-10) (Link da banca não disponível)
# - Concurso Professor Estadual (Data: 2025-11-05) (Link da banca não disponível)
# - Concurso Bombeiros (Data: 2025-06-20) (Link da banca não disponível)
# Digite o estado que você deseja buscar: RJ
#
# Concursos encontrados para o estado de 'RJ':
# - Concurso Polícia Federal (https://www.cebraspe.org.br/)
# - Concurso Professor Estadual (Link da banca não disponível)

# %%
# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, data_concurso=None, data_avaliacao=None, banca=None, link_banca=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Data do Concurso': data_concurso,
        'Data da Avaliação': data_avaliacao,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo a data da avaliação)
adicionar_concurso("Concurso Polícia Federal", "RJ", "2025-08-15", "2025-09-28", "Cebraspe", "https://www.cebraspe.org.br/")
adicionar_concurso("Concurso Guarda Municipal", "SP", "2025-09-22", "2025-11-10", "Vunesp", "https://www.vunesp.com.br/")
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "2025-10-10", "2025-12-01", "IBGP")
adicionar_concurso("Concurso Professor Estadual", "RJ", "2025-11-05", "2026-01-15")
adicionar_concurso("Concurso Bombeiros", "MG", "2025-06-20", "2025-07-30") # Adicionando um concurso com data de avaliação em 2025

# Vamos ver como está a nossa lista de concursos agora
print("\nLista de Concursos Adicionados (com data da avaliação):")
for concurso in lista_de_concursos:
    print(concurso)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
# Concurso 'Concurso Bombeiros' adicionado com sucesso.
#
# Lista de Concursos Adicionados (com data da avaliação):
# {'Nome do Concurso': 'Concurso Polícia Federal', 'Estado': 'RJ', 'Data do Concurso': '2025-08-15', 'Data da Avaliação': '2025-09-28', 'Banca Responsável': 'Cebraspe', 'Link da Banca Responsável': 'https://www.cebraspe.org.br/'}
# {'Nome do Concurso': 'Concurso Guarda Municipal', 'Estado': 'SP', 'Data do Concurso': '2025-09-22', 'Data da Avaliação': '2025-11-10', 'Banca Responsável': 'Vunesp', 'Link da Banca Responsável': 'https://www.vunesp.com.br/'}
# {'Nome do Concurso': 'Concurso Tribunal de Justiça', 'Estado': 'MG', 'Data do Concurso': '2025-10-10', 'Data da Avaliação': '2025-12-01', 'Banca Responsável': 'IBGP', 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Professor Estadual', 'Estado': 'RJ', 'Data do Concurso': '2025-11-05', 'Data da Avaliação': '2026-01-15', 'Banca Responsável': None, 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Bombeiros', 'Estado': 'MG', 'Data do Concurso': '2025-06-20', 'Data da Avaliação': '2025-07-30', 'Banca Responsável': None, 'Link da Banca Responsável': None}

# %%
# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, nivel=None, data_concurso=None, data_avaliacao=None, banca=None, link_banca=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Nível': nivel,
        'Data do Concurso': data_concurso,
        'Data da Avaliação': data_avaliacao,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo o nível)
adicionar_concurso("Concurso Polícia Federal", "RJ", "Superior", "2025-08-15", "2025-09-28", "Cebraspe", "https://www.cebraspe.org.br/")
adicionar_concurso("Concurso Guarda Municipal", "SP", "Médio", "2025-09-22", "2025-11-10", "Vunesp", "https://www.vunesp.com.br/")
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "Superior", "2025-10-10", "2025-12-01", "IBGP")
adicionar_concurso("Concurso Professor Estadual", "RJ", "Superior", "2025-11-05", "2026-01-15")
adicionar_concurso("Concurso Bombeiros", "MG", "Médio", "2025-06-20", "2025-07-30")
adicionar_concurso("Concurso Banco Central", "DF", "Superior") # Adicionando sem outras datas

# Vamos ver como está a nossa lista de concursos agora
print("\nLista de Concursos Adicionados (com nível):")
for concurso in lista_de_concursos:
    print(concurso)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
# Concurso 'Concurso Bombeiros' adicionado com sucesso.
# Concurso 'Concurso Banco Central' adicionado com sucesso.
#
# Lista de Concursos Adicionados (com nível):
# {'Nome do Concurso': 'Concurso Polícia Federal', 'Estado': 'RJ', 'Nível': 'Superior', 'Data do Concurso': '2025-08-15', 'Data da Avaliação': '2025-09-28', 'Banca Responsável': 'Cebraspe', 'Link da Banca Responsável': 'https://www.cebraspe.org.br/'}
# {'Nome do Concurso': 'Concurso Guarda Municipal', 'Estado': 'SP', 'Nível': 'Médio', 'Data do Concurso': '2025-09-22', 'Data da Avaliação': '2025-11-10', 'Banca Responsável': 'Vunesp', 'Link da Banca Responsável': 'https://www.vunesp.com.br/'}
# {'Nome do Concurso': 'Concurso Tribunal de Justiça', 'Estado': 'MG', 'Nível': 'Superior', 'Data do Concurso': '2025-10-10', 'Data da Avaliação': '2025-12-01', 'Banca Responsável': 'IBGP', 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Professor Estadual', 'Estado': 'RJ', 'Nível': 'Superior', 'Data do Concurso': '2025-11-05', 'Data da Avaliação': '2026-01-15', 'Banca Responsável': None, 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Bombeiros', 'Estado': 'MG', 'Nível': 'Médio', 'Data do Concurso': '2025-06-20', 'Data da Avaliação': '2025-07-30', 'Banca Responsável': None, 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Banco Central', 'Estado': 'DF', 'Nível': 'Superior', 'Data do Concurso': None, 'Data da Avaliação': None, 'Banca Responsável': None, 'Link da Banca Responsável': None}

# %%
from datetime import datetime

# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, nivel=None, data_concurso=None, data_avaliacao=None, banca=None, link_banca=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Nível': nivel,
        'Data do Concurso': data_concurso,
        'Data da Avaliação': data_avaliacao,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo o nível)
adicionar_concurso("Concurso Polícia Federal", "RJ", "Superior", "2025-08-15", "2025-09-28", "Cebraspe", "https://www.cebraspe.org.br/")
adicionar_concurso("Concurso Guarda Municipal", "SP", "Médio", "2025-09-22", "2025-11-10", "Vunesp", "https://www.vunesp.com.br/")
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "Superior", "2025-10-10", "2025-12-01", "IBGP")
adicionar_concurso("Concurso Professor Estadual", "RJ", "Superior", "2025-11-05", "2026-01-15")
adicionar_concurso("Concurso Bombeiros", "MG", "Médio", "2025-06-20", "2025-07-30")
adicionar_concurso("Concurso Banco Central", "DF", "Superior") # Adicionando sem outras datas

# Vamos ver como está a nossa lista de concursos agora
print("\nLista de Concursos Adicionados (com nível):")
for concurso in lista_de_concursos:
    print(concurso)

# Função para listar todos os concursos com data de 2025
def listar_concursos_2025():
    concursos_2025 = []
    for concurso in lista_de_concursos:
        if concurso['Data do Concurso'] and '2025' in concurso['Data do Concurso']:
            concursos_2025.append(concurso)

    if concursos_2025:
        print("\nConcursos com data prevista para 2025:")
        for concurso in concursos_2025:
            print(f"- {concurso['Nome do Concurso']}", end=" ")
            if concurso['Nível']:
                print(f"(Nível: {concurso['Nível']})", end=" ")
            else:
                print("(Nível: Não informado)", end=" ")
            if concurso['Data do Concurso']:
                print(f"(Data: {concurso['Data do Concurso']})", end=" ")
            else:
                print("(Data: A ser definida)", end=" ")
            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print("\nNenhum concurso com data prevista para 2025 foi encontrado.")

# Função para listar as avaliações que vão acontecer (em 2025 ou depois)
def listar_avaliacoes_futuras():
    avaliacoes_futuras = []
    hoje = datetime.now().date()
    ano_atual = hoje.year

    print(f"\nAvaliações de concursos agendadas para {ano_atual} e depois:")
    encontrou_avaliacao = False
    for concurso in lista_de_concursos:
        if concurso['Data da Avaliação']:
            try:
                data_avaliacao_obj = datetime.strptime(concurso['Data da Avaliação'], '%Y-%m-%d').date()
                if data_avaliacao_obj >= hoje:
                    data_formatada = data_avaliacao_obj.strftime('%d-%m-%Y')
                    print(f"- {concurso['Nome do Concurso']} (Nível: {concurso['Nível'] if concurso['Nível'] else 'Não informado'}) (Avaliação: {data_formatada})", end=" ")
                    if concurso['Link da Banca Responsável']:
                        print(f"({concurso['Link da Banca Responsável']})")
                    else:
                        print("(Link da banca não disponível)")
                    encontrou_avaliacao = True
            except ValueError:
                print(f"Aviso: Formato de data inválido para a avaliação de '{concurso['Nome do Concurso']}'.")

    if not encontrou_avaliacao:
        print("Nenhuma avaliação de concurso futura encontrada.")

# Função para buscar concursos por estado
def buscar_concursos_por_estado(estado_busca):
    estado_busca_upper = estado_busca.upper()
    concursos_encontrados = []
    for concurso in lista_de_concursos:
        if concurso['Estado'] == estado_busca_upper:
            concursos_encontrados.append(concurso)

    if concursos_encontrados:
        print(f"\nConcursos encontrados para o estado de '{estado_busca}':")
        for concurso in concursos_encontrados:
            print(f"- {concurso['Nome do Concurso']} (Nível: {concurso['Nível'] if concurso['Nível'] else 'Não informado'})", end=" ")
            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print(f"\nNenhum concurso encontrado para o estado de '{estado_busca}'.")

# Exemplos de uso das funções
listar_avaliacoes_futuras()
listar_concursos_2025()

# Agora a busca por estado será solicitada aqui
estado_para_buscar = input("Digite o estado que você deseja buscar: ")
buscar_concursos_por_estado(estado_para_buscar)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
# Concurso 'Concurso Bombeiros' adicionado com sucesso.
# Concurso 'Concurso Banco Central' adicionado com sucesso.
#
# Lista de Concursos Adicionados (com nível):
# {'Nome do Concurso': 'Concurso Polícia Federal', 'Estado': 'RJ', 'Nível': 'Superior', 'Data do Concurso': '2025-08-15', 'Data da Avaliação': '2025-09-28', 'Banca Responsável': 'Cebraspe', 'Link da Banca Responsável': 'https://www.cebraspe.org.br/'}
# {'Nome do Concurso': 'Concurso Guarda Municipal', 'Estado': 'SP', 'Nível': 'Médio', 'Data do Concurso': '2025-09-22', 'Data da Avaliação': '2025-11-10', 'Banca Responsável': 'Vunesp', 'Link da Banca Responsável': 'https://www.vunesp.com.br/'}
# {'Nome do Concurso': 'Concurso Tribunal de Justiça', 'Estado': 'MG', 'Nível': 'Superior', 'Data do Concurso': '2025-10-10', 'Data da Avaliação': '2025-12-01', 'Banca Responsável': 'IBGP', 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Professor Estadual', 'Estado': 'RJ', 'Nível': 'Superior', 'Data do Concurso': '2025-11-05', 'Data da Avaliação': '2026-01-15', 'Banca Responsável': None, 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Bombeiros', 'Estado': 'MG', 'Nível': 'Médio', 'Data do Concurso': '2025-06-20', 'Data da Avaliação': '2025-07-30', 'Banca Responsável': None, 'Link da Banca Responsável': None}
# {'Nome do Concurso': 'Concurso Banco Central', 'Estado': 'DF', 'Nível': 'Superior', 'Data do Concurso': None, 'Data da Avaliação': None, 'Banca Responsável': None, 'Link da Banca Responsável': None}
#
# Avaliações de concursos agendadas para 2025 e depois:
# - Concurso Polícia Federal (Nível: Superior) (Avaliação: 28-09-2025) (https://www.cebraspe.org.br/)
# - Concurso Guarda Municipal (Nível: Médio) (Avaliação: 10-11-2025) (https://www.vunesp.com.br/)
# - Concurso Tribunal de Justiça (Nível: Superior) (Avaliação: 01-12-2025) (Link da banca não disponível)
# - Concurso Professor Estadual (Nível: Superior) (Avaliação: 15-01-2026) (Link da banca não disponível)
# - Concurso Bombeiros (Nível: Médio) (Avaliação: 30-07-2025) (Link da banca não disponível)
#
# Concursos com data prevista para 2025:
# - Concurso Polícia Federal (Nível: Superior) (Data: 2025-08-15) (https://www.cebraspe.org.br/)
# - Concurso Guarda Municipal (Nível: Médio) (Data: 2025-09-22) (https://www.vunesp.com.br/)
# - Concurso Tribunal de Justiça (Nível: Superior) (Data: 2025-10-10) (Link da banca não disponível)
# - Concurso Professor Estadual (Nível: Superior) (Data: 2025-11-05) (Link da banca não disponível)
# - Concurso Bombeiros (Nível: Médio) (Data: 2025-06-20) (Link da banca não disponível)
# Digite o estado que você deseja buscar: mg
#
# Concursos encontrados para o estado de 'mg':
# - Concurso Tribunal de Justiça (Nível: Superior) (Link da banca não disponível)
# - Concurso Bombeiros (Nível: Médio) (Link da banca não disponível)

# %%
from datetime import datetime

# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, nivel=None, data_concurso=None, data_avaliacao=None, banca=None, link_banca=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Nível': nivel,
        'Data do Concurso': data_concurso,
        'Data da Avaliação': data_avaliacao,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo o nível)
adicionar_concurso("Concurso Polícia Federal", "RJ", "Superior", "2025-08-15", "2025-09-28", "Cebraspe", "https://www.cebraspe.org.br/")
adicionar_concurso("Concurso Guarda Municipal", "SP", "Médio", "2025-09-22", "2025-11-10", "Vunesp", "https://www.vunesp.com.br/")
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "Superior", "2025-10-10", "2025-12-01", "IBGP")
adicionar_concurso("Concurso Professor Estadual", "RJ", "Superior", "2025-11-05", "2026-01-15")
adicionar_concurso("Concurso Bombeiros", "MG", "Médio", "2025-06-20", "2025-07-30")
adicionar_concurso("Concurso Banco Central", "DF", "Superior") # Adicionando sem outras datas

# Função para buscar concursos por estado
def buscar_concursos_por_estado(estado_busca):
    estado_busca_upper = estado_busca.upper()
    concursos_encontrados = []
    for concurso in lista_de_concursos:
        if concurso['Estado'] == estado_busca_upper:
            concursos_encontrados.append(concurso)

    if concursos_encontrados:
        print(f"\nConcursos encontrados para o estado de '{estado_busca}':")
        for concurso in concursos_encontrados:
            print(f"- {concurso['Nome do Concurso']} (Nível: {concurso['Nível'] if concurso['Nível'] else 'Não informado'})", end=" ")
            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print(f"\nNenhum concurso encontrado para o estado de '{estado_busca}'.")

# Agora a busca por estado será solicitada aqui
estado_para_buscar = input("Digite o estado que você deseja buscar: ")
buscar_concursos_por_estado(estado_para_buscar)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
# Concurso 'Concurso Bombeiros' adicionado com sucesso.
# Concurso 'Concurso Banco Central' adicionado com sucesso.
# Digite o estado que você deseja buscar: RJ
#
# Concursos encontrados para o estado de 'RJ':
# - Concurso Polícia Federal (Nível: Superior) (https://www.cebraspe.org.br/)
# - Concurso Professor Estadual (Nível: Superior) (Link da banca não disponível)

# %%
from datetime import datetime

# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, nivel=None, data_concurso=None, inicio_inscricoes=None, data_avaliacao=None, banca=None, link_banca=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Nível': nivel,
        'Data do Concurso': data_concurso,
        'Início das Inscrições': inicio_inscricoes,
        'Data da Avaliação': data_avaliacao,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo a data do concurso e início das inscrições)
adicionar_concurso("Concurso Polícia Federal", "RJ", "Superior", "2025-08-15", "2025-06-01", "2025-09-28", "Cebraspe", "https://www.cebraspe.org.br/")
adicionar_concurso("Concurso Guarda Municipal", "SP", "Médio", "2025-09-22", "2025-07-10", "2025-11-10", "Vunesp", "https://www.vunesp.com.br/")
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "Superior", "2025-10-10", "2025-08-05", "2025-12-01", "IBGP")
adicionar_concurso("Concurso Professor Estadual", "RJ", "Superior", "2025-11-05", "2025-09-15", "2026-01-15")
adicionar_concurso("Concurso Bombeiros", "MG", "Médio", "2025-06-20", "2025-05-20", "2025-07-30")
adicionar_concurso("Concurso Banco Central", "DF", "Superior", None, "2025-07-01") # Adicionando sem data do concurso

# Função para buscar concursos por estado
def buscar_concursos_por_estado(estado_busca):
    estado_busca_upper = estado_busca.upper()
    concursos_encontrados = []
    for concurso in lista_de_concursos:
        if concurso['Estado'] == estado_busca_upper:
            concursos_encontrados.append(concurso)

    if concursos_encontrados:
        print(f"\nConcursos encontrados para o estado de '{estado_busca}':")
        for concurso in concursos_encontrados:
            print(f"- {concurso['Nome do Concurso']} (Nível: {concurso['Nível'] if concurso['Nível'] else 'Não informado'})", end=" ")
            if concurso['Data do Concurso']:
                try:
                    data_concurso_obj = datetime.strptime(concurso['Data do Concurso'], '%Y-%m-%d').date()
                    data_concurso_formatada = data_concurso_obj.strftime('%d-%m-%Y')
                    print(f"(Data do Concurso: {data_concurso_formatada})", end=" ")
                except ValueError:
                    print("(Data do Concurso: Formato inválido)", end=" ")
            else:
                print("(Data do Concurso: A ser definida)", end=" ")

            if concurso['Início das Inscrições']:
                try:
                    inicio_inscricoes_obj = datetime.strptime(concurso['Início das Inscrições'], '%Y-%m-%d').date()
                    inicio_inscricoes_formatada = inicio_inscricoes_obj.strftime('%d-%m-%Y')
                    print(f"(Início Inscrições: {inicio_inscricoes_formatada})", end=" ")
                except ValueError:
                    print("(Início Inscrições: Formato inválido)", end=" ")
            else:
                print("(Início Inscrições: A ser definido)", end=" ")

            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print(f"\nNenhum concurso encontrado para o estado de '{estado_busca}'.")

# Agora a busca por estado será solicitada aqui
estado_para_buscar = input("Digite o estado que você deseja buscar: ")
buscar_concursos_por_estado(estado_para_buscar)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
# Concurso 'Concurso Bombeiros' adicionado com sucesso.
# Concurso 'Concurso Banco Central' adicionado com sucesso.
# Digite o estado que você deseja buscar: RJ
#
# Concursos encontrados para o estado de 'RJ':
# - Concurso Polícia Federal (Nível: Superior) (Data do Concurso: 15-08-2025) (Início Inscrições: 01-06-2025) (https://www.cebraspe.org.br/)
# - Concurso Professor Estadual (Nível: Superior) (Data do Concurso: 05-11-2025) (Início Inscrições: 15-09-2025) (Link da banca não disponível)

# %%
# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, nivel=None, data_concurso=None, inicio_inscricoes=None, data_avaliacao=None, banca=None, link_banca=None, valor_inscricao=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Nível': nivel,
        'Data do Concurso': data_concurso,
        'Início das Inscrições': inicio_inscricoes,
        'Data da Avaliação': data_avaliacao,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca,
        'Valor da Inscrição': valor_inscricao
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo o valor da inscrição)
adicionar_concurso("Concurso Polícia Federal", "RJ", "Superior", "2025-08-15", "2025-06-01", "2025-09-28", "Cebraspe", "https://www.cebraspe.org.br/", 120.00)
adicionar_concurso("Concurso Guarda Municipal", "SP", "Médio", "2025-09-22", "2025-07-10", "2025-11-10", "Vunesp", "https://www.vunesp.com.br/", 85.50)
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "Superior", "2025-10-10", "2025-08-05", "2025-12-01", "IBGP", 150.00)
adicionar_concurso("Concurso Professor Estadual", "RJ", "Superior", "2025-11-05", "2025-09-15", "2026-01-15", None, None, 90.00)
adicionar_concurso("Concurso Bombeiros", "MG", "Médio", "2025-06-20", "2025-05-20", "2025-07-30", None, None, 70.00)
adicionar_concurso("Concurso Banco Central", "DF", "Superior", None, "2025-07-01", None, None, None, 180.00) # Adicionando sem data do concurso

# Função para buscar concursos por estado
def buscar_concursos_por_estado(estado_busca):
    estado_busca_upper = estado_busca.upper()
    concursos_encontrados = []
    for concurso in lista_de_concursos:
        if concurso['Estado'] == estado_busca_upper:
            concursos_encontrados.append(concurso)

    if concursos_encontrados:
        print(f"\nConcursos encontrados para o estado de '{estado_busca}':")
        for concurso in concursos_encontrados:
            print(f"- {concurso['Nome do Concurso']} (Nível: {concurso['Nível'] if concurso['Nível'] else 'Não informado'})", end=" ")
            if concurso['Valor da Inscrição'] is not None:
                print(f"(Valor: R$ {concurso['Valor da Inscrição']:.2f})", end=" ")
            else:
                print("(Valor: A ser definido)", end=" ")
            if concurso['Data do Concurso']:
                try:
                    data_concurso_obj = datetime.strptime(concurso['Data do Concurso'], '%Y-%m-%d').date()
                    data_concurso_formatada = data_concurso_obj.strftime('%d-%m-%Y')
                    print(f"(Data do Concurso: {data_concurso_formatada})", end=" ")
                except ValueError:
                    print("(Data do Concurso: Formato inválido)", end=" ")
            else:
                print("(Data do Concurso: A ser definida)", end=" ")

            if concurso['Início das Inscrições']:
                try:
                    inicio_inscricoes_obj = datetime.strptime(concurso['Início das Inscrições'], '%Y-%m-%d').date()
                    inicio_inscricoes_formatada = inicio_inscricoes_obj.strftime('%d-%m-%Y')
                    print(f"(Início Inscrições: {inicio_inscricoes_formatada})", end=" ")
                except ValueError:
                    print("(Início Inscrições: Formato inválido)", end=" ")
            else:
                print("(Início Inscrições: A ser definido)", end=" ")

            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print(f"\nNenhum concurso encontrado para o estado de '{estado_busca}'.")

# Agora a busca por estado será solicitada aqui
estado_para_buscar = input("Digite o estado que você deseja buscar: ")
buscar_concursos_por_estado(estado_para_buscar)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
# Concurso 'Concurso Bombeiros' adicionado com sucesso.
# Concurso 'Concurso Banco Central' adicionado com sucesso.
# Digite o estado que você deseja buscar: SP
#
# Concursos encontrados para o estado de 'SP':
# - Concurso Guarda Municipal (Nível: Médio) (Valor: R$ 85.50)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0106003da1ae> in <cell line: 0>()
#      71 # Agora a busca por estado será solicitada aqui
#      72 estado_para_buscar = input("Digite o estado que você deseja buscar: ")
# ---> 73 buscar_concursos_por_estado(estado_para_buscar)
#
# <ipython-input-4-0106003da1ae> in buscar_concursos_por_estado(estado_busca)
#      44             if concurso['Data do Concurso']:
#      45                 try:
# ---> 46                     data_concurso_obj = datetime.strptime(concurso['Data do Concurso'], '%Y-%m-%d').date()
#      47                     data_concurso_formatada = data_concurso_obj.strftime('%d-%m-%Y')
#      48                     print(f"(Data do Concurso: {data_concurso_formatada})", end=" ")
#
# NameError: name 'datetime' is not defined

# %%
from datetime import datetime

# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, nivel=None, data_concurso=None, inicio_inscricoes=None, data_avaliacao=None, banca=None, link_banca=None, valor_inscricao=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Nível': nivel,
        'Data do Concurso': data_concurso,
        'Início das Inscrições': inicio_inscricoes,
        'Data da Avaliação': data_avaliacao,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca,
        'Valor da Inscrição': valor_inscricao
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo o valor da inscrição)
adicionar_concurso("Concurso Polícia Federal", "RJ", "Superior", "2025-08-15", "2025-06-01", "2025-09-28", "Cebraspe", "https://www.cebraspe.org.br/", 120.00)
adicionar_concurso("Concurso Guarda Municipal", "SP", "Médio", "2025-09-22", "2025-07-10", "2025-11-10", "Vunesp", "https://www.vunesp.com.br/", 85.50)
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "Superior", "2025-10-10", "2025-08-05", "2025-12-01", "IBGP", 150.00)
adicionar_concurso("Concurso Professor Estadual", "RJ", "Superior", "2025-11-05", "2025-09-15", "2026-01-15", None, None, 90.00)
adicionar_concurso("Concurso Bombeiros", "MG", "Médio", "2025-06-20", "2025-05-20", "2025-07-30", None, None, 70.00)
adicionar_concurso("Concurso Banco Central", "DF", "Superior", None, "2025-07-01", None, None, None, 180.00) # Adicionando sem data do concurso

# Função para buscar concursos por estado
def buscar_concursos_por_estado(estado_busca):
    estado_busca_upper = estado_busca.upper()
    concursos_encontrados = []
    for concurso in lista_de_concursos:
        if concurso['Estado'] == estado_busca_upper:
            concursos_encontrados.append(concurso)

    if concursos_encontrados:
        print(f"\nConcursos encontrados para o estado de '{estado_busca}':")
        for concurso in concursos_encontrados:
            print(f"- {concurso['Nome do Concurso']} (Nível: {concurso['Nível'] if concurso['Nível'] else 'Não informado'})", end=" ")
            if concurso['Valor da Inscrição'] is not None:
                print(f"(Valor: R$ {concurso['Valor da Inscrição']:.2f})", end=" ")
            else:
                print("(Valor: A ser definido)", end=" ")
            if concurso['Data do Concurso']:
                try:
                    data_concurso_obj = datetime.strptime(concurso['Data do Concurso'], '%Y-%m-%d').date()
                    data_concurso_formatada = data_concurso_obj.strftime('%d-%m-%Y')
                    print(f"(Data do Concurso: {data_concurso_formatada})", end=" ")
                except ValueError:
                    print("(Data do Concurso: Formato inválido)", end=" ")
            else:
                print("(Data do Concurso: A ser definida)", end=" ")

            if concurso['Início das Inscrições']:
                try:
                    inicio_inscricoes_obj = datetime.strptime(concurso['Início das Inscrições'], '%Y-%m-%d').date()
                    inicio_inscricoes_formatada = inicio_inscricoes_obj.strftime('%d-%m-%Y')
                    print(f"(Início Inscrições: {inicio_inscricoes_formatada})", end=" ")
                except ValueError:
                    print("(Início Inscrições: Formato inválido)", end=" ")
            else:
                print("(Início Inscrições: A ser definido)", end=" ")

            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print(f"\nNenhum concurso encontrado para o estado de '{estado_busca}'.")

# Agora a busca por estado será solicitada aqui
estado_para_buscar = input("Digite o estado que você deseja buscar: ")
buscar_concursos_por_estado(estado_para_buscar)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
# Concurso 'Concurso Bombeiros' adicionado com sucesso.
# Concurso 'Concurso Banco Central' adicionado com sucesso.
# Digite o estado que você deseja buscar: SP
#
# Concursos encontrados para o estado de 'SP':
# - Concurso Guarda Municipal (Nível: Médio) (Valor: R$ 85.50) (Data do Concurso: 22-09-2025) (Início Inscrições: 10-07-2025) (https://www.vunesp.com.br/)

# %%
# Estrutura para armazenar os dados dos concursos
lista_de_concursos = []

# Função para adicionar um novo concurso
def adicionar_concurso(nome, estado, nivel=None, data_concurso=None, inicio_inscricoes=None, data_avaliacao=None, banca=None, link_banca=None, valor_inscricao=None, quantidade_vagas=None):
    concurso = {
        'Nome do Concurso': nome,
        'Estado': estado.upper(),
        'Nível': nivel,
        'Data do Concurso': data_concurso,
        'Início das Inscrições': inicio_inscricoes,
        'Data da Avaliação': data_avaliacao,
        'Banca Responsável': banca,
        'Link da Banca Responsável': link_banca,
        'Valor da Inscrição': valor_inscricao,
        'Quantidade de Vagas': quantidade_vagas
    }
    lista_de_concursos.append(concurso)
    print(f"Concurso '{nome}' adicionado com sucesso.")

# Exemplos de como usar a função para adicionar concursos (incluindo a quantidade de vagas)
adicionar_concurso("Concurso Polícia Federal", "RJ", "Superior", "2025-08-15", "2025-06-01", "2025-09-28", "Cebraspe", "https://www.cebraspe.org.br/", 120.00, 150)
adicionar_concurso("Concurso Guarda Municipal", "SP", "Médio", "2025-09-22", "2025-07-10", "2025-11-10", "Vunesp", "https://www.vunesp.com.br/", 85.50, 50)
adicionar_concurso("Concurso Tribunal de Justiça", "MG", "Superior", "2025-10-10", "2025-08-05", "2025-12-01", "IBGP", 150.00, 30)
adicionar_concurso("Concurso Professor Estadual", "RJ", "Superior", "2025-11-05", "2025-09-15", "2026-01-15", None, None, 90.00, 200)
adicionar_concurso("Concurso Bombeiros", "MG", "Médio", "2025-06-20", "2025-05-20", "2025-07-30", None, None, 70.00, 100)
adicionar_concurso("Concurso Banco Central", "DF", "Superior", None, "2025-07-01", None, None, None, 180.00, 25) # Adicionando sem data do concurso

# Função para buscar concursos por estado
def buscar_concursos_por_estado(estado_busca):
    estado_busca_upper = estado_busca.upper()
    concursos_encontrados = []
    for concurso in lista_de_concursos:
        if concurso['Estado'] == estado_busca_upper:
            concursos_encontrados.append(concurso)

    if concursos_encontrados:
        print(f"\nConcursos encontrados para o estado de '{estado_busca}':")
        for concurso in concursos_encontrados:
            print(f"- {concurso['Nome do Concurso']} (Nível: {concurso['Nível'] if concurso['Nível'] else 'Não informado'})", end=" ")
            if concurso['Quantidade de Vagas'] is not None:
                print(f"(Vagas: {concurso['Quantidade de Vagas']})", end=" ")
            else:
                print("(Vagas: A ser definida)", end=" ")
            if concurso['Valor da Inscrição'] is not None:
                print(f"(Valor: R$ {concurso['Valor da Inscrição']:.2f})", end=" ")
            else:
                print("(Valor: A ser definido)", end=" ")
            if concurso['Data do Concurso']:
                try:
                    data_concurso_obj = datetime.strptime(concurso['Data do Concurso'], '%Y-%m-%d').date()
                    data_concurso_formatada = data_concurso_obj.strftime('%d-%m-%Y')
                    print(f"(Data do Concurso: {data_concurso_formatada})", end=" ")
                except ValueError:
                    print("(Data do Concurso: Formato inválido)", end=" ")
            else:
                print("(Data do Concurso: A ser definida)", end=" ")

            if concurso['Início das Inscrições']:
                try:
                    inicio_inscricoes_obj = datetime.strptime(concurso['Início das Inscrições'], '%Y-%m-%d').date()
                    inicio_inscricoes_formatada = inicio_inscricoes_obj.strftime('%d-%m-%Y')
                    print(f"(Início Inscrições: {inicio_inscricoes_formatada})", end=" ")
                except ValueError:
                    print("(Início Inscrições: Formato inválido)", end=" ")
            else:
                print("(Início Inscrições: A ser definido)", end=" ")

            if concurso['Link da Banca Responsável']:
                print(f"({concurso['Link da Banca Responsável']})")
            else:
                print("(Link da banca não disponível)")
    else:
        print(f"\nNenhum concurso encontrado para o estado de '{estado_busca}'.")

# Agora a busca por estado será solicitada aqui
estado_para_buscar = input("Digite o estado que você deseja buscar: ")
buscar_concursos_por_estado(estado_para_buscar)
# Out:
# Concurso 'Concurso Polícia Federal' adicionado com sucesso.
# Concurso 'Concurso Guarda Municipal' adicionado com sucesso.
# Concurso 'Concurso Tribunal de Justiça' adicionado com sucesso.
# Concurso 'Concurso Professor Estadual' adicionado com sucesso.
# Concurso 'Concurso Bombeiros' adicionado com sucesso.
# Concurso 'Concurso Banco Central' adicionado com sucesso.
# Digite o estado que você deseja buscar: RJ
#
# Concursos encontrados para o estado de 'RJ':
# - Concurso Polícia Federal (Nível: Superior) (Vagas: 150) (Valor: R$ 120.00) (Data do Concurso: 15-08-2025) (Início Inscrições: 01-06-2025) (https://www.cebraspe.org.br/)
# - Concurso Professor Estadual (Nível: Superior) (Vagas: 200) (Valor: R$ 90.00) (Data do Concurso: 05-11-2025) (Início Inscrições: 15-09-2025) (Link da banca não disponível)
